# %% [markdown]
# # Importing Libraries and orders_products_combined.pkl and products.csv

# %%
import pandas as pd
import numpy as np
import os

# %%
path=r'/Users/stefaniadaskalaki/Data Immersion/4 Achievement Python/CF4.2 Instacart Basket Analysis'

# %%
df_orders_products_combined=pd.read_pickle(os.path.join(path, '02. Data', '02. Prepared Data', 'orders_products_combined.pkl'))

# %%
df_prods = pd.read_csv(os.path.join(path, '02. Data', '02. Prepared Data', 'products_checked.csv'),index_col=[0])

# %% [markdown]
# ## Checking the DF (it should be the same as the one you exported—always check!)

# %%
df_orders_products_combined
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0                    0           0   2539329        1             1
# 1                    0           0   2539329        1             1
# 2                    0           0   2539329        1             1
# 3                    0           0   2539329        1             1
# 4                    0           0   2539329        1             1
# ...                ...         ...       ...      ...           ...
# 32434484       3421081     3421081   2977660   206209            13
# 32434485       3421081     3421081   2977660   206209            13
# 32434486       3421081     3421081   2977660   206209            13
# 32434487       3421081     3421081   2977660   206209            13
# 32434488       3421081     3421081   2977660   206209            13
#
#           order_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                         2                  8                     NaN
# ...

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 13)

# %%
df_orders_products_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32434489 entries, 0 to 32434488
# Data columns (total 13 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0.1            int64
#  1   Unnamed: 0              int64
#  2   order_id                int64
#  3   user_id                 int64
#  4   order_number            int64
#  5   order_day_of_week       int64
#  6   order_hour_of_day       int64
#  7   days_since_prior_order  float64
#  8   new_customer            bool
#  9   product_id              int64
#  10  add_to_cart_order       int64
#  11  reordered               int64
#  12  _merge                  category
# dtypes: bool(1), category(1), float64(1), int64(10)
# memory usage: 3.0 GB

# %% [markdown]
# ### Dropping Unnamed: 0.1 and Unnamed: 0 columns

# %%
df_orders_products_combined.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2539329        1             1                  2
# 2          2539329        1             1                  2
# 3          2539329        1             1                  2
# 4          2539329        1             1                  2
# ...            ...      ...           ...                ...
# 32434484   2977660   206209            13                  1
# 32434485   2977660   206209            13                  1
# 32434486   2977660   206209            13                  1
# 32434487   2977660   206209            13                  1
# 32434488   2977660   206209            13                  1
#
#           order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 0                         8                     NaN          True         196
# ...

# %%
df_orders_products_combined=df_orders_products_combined.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)

# %% [markdown]
# ### Changing data type for order_id, user_id, product_id

# %%
df_orders_products_combined['order_id'] = df_orders_products_combined['order_id'].astype('str')

# %%
df_orders_products_combined['order_id'].dtype
# Out:
# dtype('O')

# %%
df_orders_products_combined['user_id'] = df_orders_products_combined['user_id'].astype('str')

# %%
df_orders_products_combined['user_id'].dtype
# Out:
# dtype('O')

# %%
df_orders_products_combined['product_id'] = df_orders_products_combined['product_id'].astype('str')

# %%
df_orders_products_combined['product_id'].dtype
# Out:
# dtype('O')

# %%
df_orders_products_combined.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                  2                  8
# 1  2539329       1             1                  2                  8
# 2  2539329       1             1                  2                  8
# 3  2539329       1             1                  2                  8
# 4  2539329       1             1                  2                  8
#
#    days_since_prior_order  new_customer product_id  add_to_cart_order  \
# 0                     NaN          True        196                  1
# 1                     NaN          True      14084                  2
# 2                     NaN          True      12427                  3
# 3                     NaN          True      26088                  4
# 4                     NaN          True      26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# ...

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %% [markdown]
# df_prods is consistent with exported version

# %% [markdown]
# ## Changing the data type for product_id, aisle_id and department_id to str

# %%
df_prods=df_prods.astype({'product_id': str, 'aisle_id': str, 'department_id': str})

# %%
print(df_prods.dtypes)
# Out:
# product_id        object
# product_name      object
# aisle_id          object
# department_id     object
# prices           float64
# dtype: object

# %% [markdown]
# # 5.Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task

# %% [markdown]
# ## Dropping _merge column

# %%
df_orders_products_combined.drop(['_merge'], axis=1)
# Out:
#          order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0         2539329       1             1                  2                  8
# 1         2539329       1             1                  2                  8
# 2         2539329       1             1                  2                  8
# 3         2539329       1             1                  2                  8
# 4         2539329       1             1                  2                  8
# ...           ...     ...           ...                ...                ...
# 32434484  2977660  206209            13                  1                 12
# 32434485  2977660  206209            13                  1                 12
# 32434486  2977660  206209            13                  1                 12
# 32434487  2977660  206209            13                  1                 12
# 32434488  2977660  206209            13                  1                 12
#
# ...

# %%
df_orders_products_combined=df_orders_products_combined.drop(['_merge'], axis=1)

# %%
df_orders_products_combined.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                  2                  8
# 1  2539329       1             1                  2                  8
# 2  2539329       1             1                  2                  8
# 3  2539329       1             1                  2                  8
# 4  2539329       1             1                  2                  8
#
#    days_since_prior_order  new_customer product_id  add_to_cart_order  \
# 0                     NaN          True        196                  1
# 1                     NaN          True      14084                  2
# 2                     NaN          True      12427                  3
# 3                     NaN          True      26088                  4
# 4                     NaN          True      26405                  5
#
#    reordered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# ## Merging df_orders_products_combined and df_prods
# since we know that both dataframes have no missing values and the common identifier (product_id) will match on both and all entries i choose the default inner merge option

# %%
df_orders_products_merged = df_orders_products_combined.merge(df_prods, on = 'product_id', indicator = True)

# %%
df_orders_products_merged.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                  2                  8
# 1  2398795       1             2                  3                  7
# 2   473747       1             3                  3                 12
# 3  2254736       1             4                  4                  7
# 4   431534       1             5                  4                 15
#
#    days_since_prior_order  new_customer product_id  add_to_cart_order  \
# 0                     NaN          True        196                  1
# 1                    15.0         False        196                  1
# 2                    21.0         False        196                  1
# 3                    29.0         False        196                  1
# 4                    28.0         False        196                  1
#
#    reordered product_name aisle_id department_id  prices _merge
# ...

# %% [markdown]
# # 6. Confirm the results of the merge using the merge flag

# %%
df_orders_products_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# # 7. Export the newly created dataframe as orders_products_merged in a suitable format (taking into consideration the size)

# %%
# checking the size of the df_orders_products_merged

df_orders_products_merged.shape
# Out:
# (32404859, 15)

# %%
# considering the size i will export it in pickle

df_orders_products_merged.to_pickle(os.path.join(path, '02. Data', '02. Prepared Data', 'orders_products_merged.pkl'))
