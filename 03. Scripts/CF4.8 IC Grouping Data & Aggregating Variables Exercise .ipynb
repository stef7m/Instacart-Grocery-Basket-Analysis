# %% [markdown]
# # Importing Libraries, orders_products_derived.pkl and checking outcome

# %%
import pandas as pd
import numpy as np
import os

# %%
path=r'/Users/stefaniadaskalaki/Data Immersion/4 Achievement Python/CF4.2 Instacart Basket Analysis'

# %%
df_ords_prods_merge=pd.read_pickle(os.path.join(path, '02. Data', '02. Prepared Data', 'orders_products_derived.pkl'))

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 19)

# %%
df_ords_prods_merge.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                  2                  8
# 1  2398795       1             2                  3                  7
# 2   473747       1             3                  3                 12
# 3  2254736       1             4                  4                  7
# 4   431534       1             5                  4                 15
#
#    days_since_prior_order  new_customer product_id  add_to_cart_order  \
# 0                     NaN          True        196                  1
# 1                    15.0         False        196                  1
# 2                    21.0         False        196                  1
# 3                    29.0         False        196                  1
# 4                    28.0         False        196                  1
#
#    reordered product_name aisle_id department_id  prices _merge  \
# ...

# %% [markdown]
# # Creating a new subset for first 1000000 rows and checking outcome

# %%
df=df_ords_prods_merge[:1000000]

# %%
df
# Out:
#        order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0       2539329       1             1                  2                  8
# 1       2398795       1             2                  3                  7
# 2        473747       1             3                  3                 12
# 3       2254736       1             4                  4                  7
# 4        431534       1             5                  4                 15
# ...         ...     ...           ...                ...                ...
# 999995  2836489  164627            14                  0                 15
# 999996  1843600  164632             5                  1                 19
# 999997   733106  164632             9                  2                 22
# 999998  1650124  164632            17                  6                 17
# 999999  3378258  164632            22                  6                 10
#
# ...

# %%
df.groupby('product_name')

# %% [markdown]
# # Perform descriptive statistic for 'order_number' when grouped by 'department_id' in order to compare the average order numbers for each department

# %% [markdown]
# ## Splitting data into groups based on 'department_id'

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636
# 4                18.825780
# 7                17.472355

# %% [markdown]
# ## using different function to get the mean without aggregation

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# 4     18.825780
# 7     17.472355
# Name: order_number, dtype: float64

# %% [markdown]
# ## Performing multple aggregations in one function

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99
# 4                18.825780   1  99
# 7                17.472355   1  99

# %% [markdown]
# # Creating loyalty flag column for loyalty customers with TRANSFORM & LOC with following criteria:
# If the maximum orders the user has made is over 40, then the customer will be labeled a “Loyal customer.”
# If the maximum orders the user has made is over 10 but less than or equal to 40, then the customer will be labeled a “Regular customer.” If the maximum orders the user has made is less than or equal to 10, then the customer will be labeled a “New customer.”

# %% [markdown]
# ### there are the folllowing steps to consider
#
# Split the data into groups based on the “user_id”column.
# Apply the transform() function on the “order_number” column to generate the maximum orders for each user.
# Create a new column, “max_order,” into which you ’ll place the results of your aggregation.

# %%
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merge.head(15)
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
# 5   3367565       1             6                  2                  7
# 6    550135       1             7                  1                  9
# 7   3108588       1             8                  1                 14
# 8   2295261       1             9                  1                 16
# 9   2550362       1            10                  4                  8
# 10  2968173      15            15                  1                  9
# 11  1870022      15            17                  2                 16
# ...

# %% [markdown]
# ### create a loyalty flag column with Loc & checking outcome

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag']='Loyal customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order']<=40)&(df_ords_prods_merge['max_order']>10),'loyalty_flag']='Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order']<=10,'loyalty_flag']='New customer'

# %%
df_ords_prods_merge['loyalty_flag'].value_counts()
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
df_ords_prods_merge['loyalty_flag']
# Out:
# 0               New customer
# 1               New customer
# 2               New customer
# 3               New customer
# 4               New customer
#                   ...
# 32404854    Regular customer
# 32404855    Regular customer
# 32404856        New customer
# 32404857        New customer
# 32404858    Regular customer
# Name: loyalty_flag, Length: 32404859, dtype: object

# %% [markdown]
# # Checking selection of mulptiple columns outcome function

# %%
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#    user_id      loyalty_flag  order_number
# 0        1      New customer             1
# 1        1      New customer             2
# 2        1      New customer             3
# 3        1      New customer             4
# 4        1      New customer             5
# 5        1      New customer             6
# 6        1      New customer             7
# 7        1      New customer             8
# 8        1      New customer             9
# 9        1      New customer            10
# 10      15  Regular customer            15
# 11      15  Regular customer            17
# 12      15  Regular customer            18
# 13      15  Regular customer            21
# 14      15  Regular customer            22
# 15      19      New customer             2
# 16      19      New customer             5
# 17      19      New customer             7
# 18      21  Regular customer            10
# 19      31  Regular customer            10
# 20      31  Regular customer            17
# ...

# %% [markdown]
# # Export df_ords_prods_merge to pickle

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, '02. Data','02. Prepared Data', 'ords_prods_merge.pkl'))
