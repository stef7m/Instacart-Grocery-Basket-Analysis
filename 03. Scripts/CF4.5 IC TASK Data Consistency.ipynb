# %% [markdown]
# # Importing Libraries and datasets products.csv and orders_wrangled.csv

# %%
import pandas as pd

# %%
import numpy as nyp

# %%
import os

# %%
path=r'/Users/stefaniadaskalaki/Data Immersion/4 Achievement Python/CF4.2 Instacart Basket Analysis'

# %%
df_prods=pd.read_csv(os.path.join(path, '02. Data', '01. Original Data', 'products.csv'), index_col=False)

# %%
df_ords=pd.read_csv(os.path.join(path, '02. Data', '02. Prepared Data', 'orders_wrangled.csv'), index_col=False)

# %% [markdown]
# # Create a dataframe

# %%
df_test=pd.DataFrame()

# %% [markdown]
# ## Create a mixed type column

# %%
df_test['mix']=['a','b',1,True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %% [markdown]
# ## Check for mixed type columns in df_test

# %%
for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix

# %% [markdown]
# ## Fix column type from mix to string

# %%
df_test['mix'] = df_test['mix'].astype('str')

# %% [markdown]
# # Finding missing values in df_prods

# %%
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %% [markdown]
# # Creating df_nan for missing values from product_name

# %%
df_nan=df_prods[df_prods['product_name'].isnull()==True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %% [markdown]
# ## Compare missing values df and df_prodcuts

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
df_nan.shape
# Out:
# (16, 5)

# %% [markdown]
# since the percentage of missing values is way lower than 5% i choose to delete the 16 entries with product name missing value

# %% [markdown]
# # Create a new df_prods_clean excluding missing values

# %%
df_prods_clean=df_prods[df_prods['product_name'].isnull()==False]

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %% [markdown]
# # Finding full row duplicates

# %%
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %% [markdown]
# # Addressing duplicates

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
df_prods_clean_no_dups=df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %% [markdown]
# Here i checked how many rows our initial df_prods_clean had then deducted the duplicates and created a new df_prods_clean_no_dups without them. The result shows that correctly 5 rows have been deleted.

# %% [markdown]
# # Export df_prods_clean_no_dups

# %%
df_prods_clean_no_dups.to_csv(os.path.join(path, '02. Data','02. Prepared Data', 'products_checked.csv'))

# %% [markdown]
# # TASK 4.5

# %% [markdown]
# ## 2.Run the df.describe() function on your df_prods dataframe. Using your new knowledge about how to interpret the output of this function, share in a markdown cell whether anything about the data looks off or should be investigated further.
# Tip: Keep an eye on min and max values!

# %%
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %% [markdown]
# The max value of product_id is 49688 which is 5 short from the total count of 49693. Additionally the max value for price is 99999 which is possibly a mistake.

# %%
df_prods.tail(10)
# Out:
#        product_id                                product_name  aisle_id  \
# 49683       49679                     Famous Chocolate Wafers        61
# 49684       49680          All Natural Creamy Caesar Dressing        89
# 49685       49681     Spaghetti with Meatballs and Sauce Meal        38
# 49686       49682                          California Limeade        98
# 49687       49683                              Cucumber Kirby        83
# 49688       49684   Vodka, Triple Distilled, Twist of Vanilla       124
# 49689       49685          En Croute Roast Hazelnut Cranberry        42
# 49690       49686                            Artisan Baguette       112
# 49691       49687  Smartblend Healthy Metabolism Dry Cat Food        41
# 49692       49688                      Fresh Foaming Cleanser        73
#
#        department_id  prices
# 49683             19     6.0
# 49684             13     4.9
# 49685              1     6.9
# 49686              7     4.3
# ...

# %%
df_prods[df_prods.duplicated()]
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %% [markdown]
# By performing a .tail(10) i can see that there is a discrepancy between product_id and index which means there must be duplicates and this confirms our findings from earlier and again proving here by performing the duplicates function.

# %%
df_prods[df_prods.prices==99999]
# Out:
#        product_id           product_name  aisle_id  department_id   prices
# 33666       33664  2 % Reduced Fat  Milk        84             16  99999.0

# %% [markdown]
# By checking which product item has the 99999 price tag proves that it is definitely an error as milk could not cost 99999.

# %% [markdown]
# # 3.Check for mixed-type data in your df_ords dataframe.

# %%
for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
    print (col)

# %% [markdown]
# since we don't get any result it means that all columns are single data type.

# %% [markdown]
# # 5.Run a check for missing values in your df_ords dataframe.
# In a markdown cell, report your findings and propose an explanation for any missing values you find.

# %%
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# order_number                   0
# order_day_of_week              0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
df_ords.head(30)
# Out:
#     Unnamed: 0  order_id  user_id  order_number  order_day_of_week  \
# 0            0   2539329        1             1                  2
# 1            1   2398795        1             2                  3
# 2            2    473747        1             3                  3
# 3            3   2254736        1             4                  4
# 4            4    431534        1             5                  4
# 5            5   3367565        1             6                  2
# 6            6    550135        1             7                  1
# 7            7   3108588        1             8                  1
# 8            8   2295261        1             9                  1
# 9            9   2550362        1            10                  4
# 10          10   1187899        1            11                  4
# 11          11   2168274        2             1                  2
# 12          12   1501582        2             2                  5
# ...

# %% [markdown]
# The only column with missing values is the days_since_prior_order with 206209 missing ones. I would think that these entries are missing because there are customers who purchased only once through the website. Additionally after I ran a check for the frist 30 entries in the df_ords I notice that every first order of each customer is marked as NaN in the days_since_prior_order column.

# %% [markdown]
# # 6.Address the missing values using an appropriate method.
# In a markdown cell, explain why you used your method of choice.

# %%
df_ords_clean=df_ords

# %%
df_ords_clean['new_customer']=df_ords['days_since_prior_order'].isnull()==True

# %%
df_ords_clean.head(30)
# Out:
#     Unnamed: 0  order_id  user_id  order_number  order_day_of_week  \
# 0            0   2539329        1             1                  2
# 1            1   2398795        1             2                  3
# 2            2    473747        1             3                  3
# 3            3   2254736        1             4                  4
# 4            4    431534        1             5                  4
# 5            5   3367565        1             6                  2
# 6            6    550135        1             7                  1
# 7            7   3108588        1             8                  1
# 8            8   2295261        1             9                  1
# 9            9   2550362        1            10                  4
# 10          10   1187899        1            11                  4
# 11          11   2168274        2             1                  2
# 12          12   1501582        2             2                  5
# ...

# %% [markdown]
# I created a new column in a new df_ords_cleam that will flag all the NaN values as 'New Customer' df_ords_clean. In this way we will be able to count/track all new customers without loosing any entries.

# %% [markdown]
# # 7.Run a check for duplicate values in your df_ords data.
# In a markdown cell, report your findings and propose an explanation for any duplicate values you find.

# %%
df_ords_clean[df_ords_clean.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, order_number, order_day_of_week, order_hour_of_day, days_since_prior_order, new_customer]
# Index: []

# %% [markdown]
# There are no duplicates in this df_ords

# %% [markdown]
# # 9.Export your final, cleaned df_prods and df_ords data as “.csv” files in your “Prepared Data” folder and give them appropriate, succinct names.

# %%
df_ords_clean.to_csv(os.path.join(path, '02. Data','02. Prepared Data', 'orders_checked.csv'))
