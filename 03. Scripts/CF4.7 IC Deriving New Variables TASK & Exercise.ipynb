# %% [markdown]
# # Importing Libraries and orders_products_merged

# %%
import pandas as pd
import numpy as nyp
import os

# %%
path=r'/Users/stefaniadaskalaki/Data Immersion/4 Achievement Python/CF4.2 Instacart Basket Analysis'

# %%
df_orders_products_merged=pd.read_pickle(os.path.join(path, '02. Data', '02. Prepared Data', 'orders_products_merged.pkl'))

# %%
df_orders_products_merged.shape
# Out:
# (32404859, 15)

# %% [markdown]
# # Creating a subset for 1000 first entries

# %%
df = df_orders_products_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 15)

# %% [markdown]
# # Define a new function price range on df

# %%
def price_label(row):
    
  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %% [markdown]
# ## Implementing new price range function on df

# %%
df['price_range']=df.apply(price_label,axis=1)
# Out:
# /var/folders/k8/6mb93rb95jd6bknf4qsf29_r0000gn/T/ipykernel_11843/3001267412.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range']=df.apply(price_label,axis=1)

# %% [markdown]
# ## Checking the outcome and the values

# %%
df.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                  2                  8
# 1  2398795       1             2                  3                  7
# 2   473747       1             3                  3                 12
# 3  2254736       1             4                  4                  7
# 4   431534       1             5                  4                 15
#
#    days_since_prior_order  new_customer product_id  add_to_cart_order  \
# 0                     NaN          True        196                  1
# 1                    15.0         False        196                  1
# 2                    21.0         False        196                  1
# 3                    29.0         False        196                  1
# 4                    28.0         False        196                  1
#
#    reordered product_name aisle_id department_id  prices _merge  \
# ...

# %%
df['price_range'].value_counts()
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %% [markdown]
# ## Checking for most expensive product

# %%
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# ## Defining price_range function with loc and checking outcome on df

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] ='High-range product'
# Out:
# /var/folders/k8/6mb93rb95jd6bknf4qsf29_r0000gn/T/ipykernel_11843/1192690144.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] ='High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] ='Low-range product'

# %%
df['price_range_loc'].value_counts()
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # Defining price_range function with loc and checking outcome on orders_products_merged

# %%
df_orders_products_merged.loc[df_orders_products_merged['prices'] > 15, 'price_range_loc'] ='High-range product'

# %%
df_orders_products_merged.loc[(df_orders_products_merged['prices'] <= 15) & (df_orders_products_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_orders_products_merged.loc[df_orders_products_merged['prices'] <= 5, 'price_range_loc'] ='Low-range product'

# %%
df_orders_products_merged['price_range_loc'].value_counts()
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # Defining which days of the week are busiest with for-loop function & combining column to df_orders_products_merged

# %% [markdown]
# ## Checking which day of the week is busiest

# %%
df_orders_products_merged['order_day_of_week'].value_counts(dropna=False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_day_of_week, dtype: int64

# %% [markdown]
# ## Creating the For-Loop function and checking outcome

# %%
result = []
for value in df_orders_products_merged['order_day_of_week']:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %% [markdown]
# ## Combining column busiest day to df_orders_products_merged & checking outcome

# %%
df_orders_products_merged['Busiest_day']=result

# %%
df_orders_products_merged['Busiest_day'].value_counts(dropna=False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: Busiest_day, dtype: int64

# %% [markdown]
# # TASK ANSWERS

# %% [markdown]
# ## 2. Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method

# %% [markdown]
# ### Checking which two days of the week are busiest and which slowest

# %%
df_orders_products_merged['order_day_of_week'].value_counts(dropna=False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_day_of_week, dtype: int64

# %% [markdown]
# The top two are the busiest days of the week and bottom two the slowest

# %% [markdown]
# ### Defining the For-Loop function and checking outcome

# %%
result_2d = []
for value in df_orders_products_merged['order_day_of_week']:
  if value in [0,1]:
    result_2d.append("Busiest days")
  elif value in [3,4]:
    result_2d.append("Slowest days")
  else:
    result_2d.append("Regularly busy")

# %%
result_2d
# Out:
# ['Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Regularly busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
# ...

# %% [markdown]
# I added in my hypotheses above both values which represented the two busiest days and accordingly the slowest days

# %% [markdown]
# ### Combining column busiest days to df_orders_products_merged & checking outcome

# %%
df_orders_products_merged['Busiest_days']=result_2d

# %% [markdown]
# ## 3. Check the values of this new column for accuracy. Note any observations in markdown format

# %%
df_orders_products_merged.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                  2                  8
# 1  2398795       1             2                  3                  7
# 2   473747       1             3                  3                 12
# 3  2254736       1             4                  4                  7
# 4   431534       1             5                  4                 15
#
#    days_since_prior_order  new_customer product_id  add_to_cart_order  \
# 0                     NaN          True        196                  1
# 1                    15.0         False        196                  1
# 2                    21.0         False        196                  1
# 3                    29.0         False        196                  1
# 4                    28.0         False        196                  1
#
#    reordered product_name aisle_id department_id  prices _merge  \
# ...

# %%
df_orders_products_merged['Busiest_days'].value_counts()
# Out:
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: Busiest_days, dtype: int64

# %% [markdown]
# ## 4. When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day”

# %% [markdown]
# ### Checking the busiest times throughout the day

# %%
df_orders_products_merged['order_hour_of_day'].value_counts(dropna=False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
df_orders_products_merged['order_number'].shape
# Out:
# (32404859,)

# %% [markdown]
# ### Defining the periods of time and checking outcome

# %%
result_time = []
for value in df_orders_products_merged['order_hour_of_day']:
  if value in [10,11,14,15,13,12,16]:
    result_time.append("Most orders")
  elif value in [5,2,3,4]:
    result_time.append("Fewest orders")
  else:
    result_time.append("Average orders")

# %%
result_time
# Out:
# ['Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
# ...

# %% [raw]
# After checking the orders frequency from highest to slowest i decided to seperate them with a success factor:
# Most orders: > 25,000
# Average orders: < 25,000 > 10,000
# Fewest orders: < 10,000
#
# ### Combining column busiest_period_of_day and checking outcome

# %%
df_orders_products_merged['busiest_period_of_day']=result_time

# %%
df_orders_products_merged.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                  2                  8
# 1  2398795       1             2                  3                  7
# 2   473747       1             3                  3                 12
# 3  2254736       1             4                  4                  7
# 4   431534       1             5                  4                 15
#
#    days_since_prior_order  new_customer product_id  add_to_cart_order  \
# 0                     NaN          True        196                  1
# 1                    15.0         False        196                  1
# 2                    21.0         False        196                  1
# 3                    29.0         False        196                  1
# 4                    28.0         False        196                  1
#
#    reordered product_name aisle_id department_id  prices _merge  \
# ...

# %% [markdown]
# ## Export df_orders_products_merged in pickle

# %%
df_orders_products_merged.to_pickle(os.path.join(path, '02. Data','02. Prepared Data', 'orders_products_derived.pkl'))
